# %% [markdown]
# [<--BACK to Xe1T analysis](https://xecluster.lngs.infn.it/dokuwiki/doku.php?id=xenon:xenon1t:analysis)

# %% [markdown]
# # Some examples for presenting an analysis note with IPython notebooks

# %% [markdown]
# *sanderb@nikhef.nl, Feb 2016. (notebook work with Jelle, Bart, Erik)*
#
# [We add a backlink at the top for ease, please include your name and date for later use.]

# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Some-examples-for-presenting-an-analysis-note-with-IPython-notebooks"><span class="toc-item-num">1 - </span>Some examples for presenting an analysis note with IPython notebooks</a></div><div class="lev2"><a href="#Summary,-overview-and-conclusion"><span class="toc-item-num">1.1 - </span>Summary, overview and conclusion</a></div><div class="lev3"><a href="#How-to-run-this-notebook:"><span class="toc-item-num">1.1.1 - </span>How to run this notebook:</a></div><div class="lev2"><a href="#Show-your-work,-not-your-code"><span class="toc-item-num">1.2 - </span>Show your work, not your code</a></div><div class="lev3"><a href="#Run-in-another-notebook"><span class="toc-item-num">1.2.1 - </span>Run in another notebook</a></div><div class="lev3"><a href="#Use-a-button"><span class="toc-item-num">1.2.2 - </span>Use a button</a></div><div class="lev2"><a href="#How-to-keep-track-of-units"><span class="toc-item-num">1.3 - </span>How to keep track of units</a></div><div class="lev2"><a href="#Help"><span class="toc-item-num">1.4 - </span>Help</a></div><div class="lev2"><a href="#Some-more-IPython-magic"><span class="toc-item-num">1.5 - </span>Some more IPython magic</a></div><div class="lev3"><a href="#Latex"><span class="toc-item-num">1.5.1 - </span>Latex</a></div><div class="lev3"><a href="#An-example-of-better-latex"><span class="toc-item-num">1.5.2 - </span>An example of better latex</a></div><div class="lev3"><a href="#Spell-checker"><span class="toc-item-num">1.5.3 - </span>Spell checker</a></div><div class="lev2"><a href="#Figures"><span class="toc-item-num">1.6 - </span>Figures</a></div><div class="lev3"><a href="#Just-one-image-of-a-cat"><span class="toc-item-num">1.6.1 - </span>Just one image of a cat</a></div><div class="lev3"><a href="#Scatter-plots"><span class="toc-item-num">1.6.2 - </span>Scatter plots</a></div>

# %% [markdown]
# ## Summary, overview and conclusion

# %% [markdown]
# [Here we say what the goal of this note is, what we have done and what our conclusion is.]
#
# My goal here is to show some example code which should help to make your Jupiter (also called IPython) notebook better for presentations. All material here are examples from within our collaboration. One important thing is that I am not saying that an Jupiter notebook is always a better way of presenting your analysis then a wiki note. Both have some pros and some cons, so please think carefully about which is the best way to present yours. The most important reason for presenting in Jupiter for myself is that the code and the analysis are read together for others to use, copy and understand.
#
# The golden rules for writing a good note can be found here: [How to write good Analysis Notes... by Marc, 2010](https://xecluster.lngs.infn.it/dokuwiki/doku.php?id=xenon:xenon100:analysis:goodnotes)
#
# In this notebook you can find information about:
# *  Hiding code
# *  Plotting options
# *  Extra features
# *

# %% [markdown]
# ### How to run this notebook:

# %% [markdown]
# [Here we specify what is needed to run the Jupiter notebook and which dependencies it has.]
# *  To run this notebook pull the code from the [github meetings page](https://github.com/XENON1T/XeAnalysisScripts/tree/master/examples)
# *  The run requirements for example are latest version of Ipython and PAX. (Ipython is auto installed under anaconda, type: 'ipython notebook' to test, 'conda update ipython' to update)
# *  To use the extensions they need to be installed first, this is all done within the 'Install_extensions.ipynb' Ipython notebook that is automatically called from this main notebook.
# *  With the same settings this notebook should run within ~2 minutes

# %% [markdown]
# ## Show your work, not your code

# %% [markdown]
# Even though we want to have the code here for others to check and run, we do not want to present every line. So two different ways to hide your code:

# %% [markdown]
# ### Run in another notebook

# %% [markdown]
# We can hide it by putting it in another jupiter notebook that we run from here by using [ipython magic](http://ipython.readthedocs.org/en/stable/interactive/magics.html):

# %%
### Run initialization - Here we put all the import, physics variables etc
# %run "initialize.ipynb"
# Out:
# Initialization done

# %%
Image(url='http://jupyter.org/assets/main-logo.svg')
# Out:
# <img src="http://jupyter.org/assets/main-logo.svg"/>

# %% [markdown]
# ###  Use a button

# %% [markdown]
# Many people are improving the Ipython/Jupyter experience by building extensions for it. To install some use the following cell once. Here we use '%%bash' magic to excecute a command line install with 'pip'. You can read the options here [Jupyter notebook extensions](https://github.com/ipython-contrib/IPython-notebook-extensions)

# %%
# %%bash
# pip install https://github.com/ipython-contrib/IPython-notebook-extensions/archive/master.zip --user

# %% [markdown]
# After the installation change 'nbextensions' instead of 'tree' in your browser to activate or deactivate any of the extensions. Now lets make the button for html export notes. (and yes we use hax again)

# %%
hax.ipython.code_hider()
# Out:
# <script>
# code_show=true
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#    } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit"
# value="Show/hide  all code in this notebook"></form>

# %% [markdown]
# ## How to keep track of units

# %% [markdown]
# When we define the physics variables we can use the units package from pax to write the original units, when we want to convert the units we can use the units.unit to get the correct units out.

# %%
tpc_size_mm = tpc_size / units.mm
print('The size of the tpc is %i mm.' % (tpc_size_mm))
# Out:
# The size of the tpc is 1000 mm.

# %% [markdown]
# ## Help

# %% [markdown]
# Every time we forget what our function does or how our data structure looks like we can use two very useful help functions. Lets start by running the hax example.

# %%
# %run 01_hax_tutorial_part1.ipynb
# Out:
# Found minitree at ./xe100_111002_2248_Basics.root

# %%
# lets append the folder where my analysis script is living
# sys.path.append("/home/erik/win/python_modules")

# %% [markdown]
# Now we want to know how to access 'data'....

# %%
#?data
#help(data)

# One usefull thing to remember with pandas is:
#data.keys()

# So now we know that we can acces it with:
#data['cs1']

# %% [markdown]
# ## Some more IPython magic

# %% [markdown]
# This is just one example, for all the magic see: [Cell magics](http://ipython.readthedocs.org/en/stable/interactive/magics.html#cell-magics)

# %%
# %%bash
# ls
# Out:
# 01_hax_tutorial_part1.ipynb
# initialize.ipynb
# Ipython_example_presentation.ipynb
# plot_functions.ipynb
# xe100_111002_2248_Basics.root

# %% [markdown]
# ### Latex

# %% [markdown]
# It is possible to use latex in the notebook. (note: a lot of latex functionality is not yet here, please find a better extension for this)

# %%
# %%latex
# Here we have a formula:
# $$ c = \sqrt{a^2 + b^2} $$
# were a is defined as $$ a = \frac{e}{\pi} $$
# Out:
# Here we have a formula:
# $$ c = \sqrt{a^2 + b^2} $$
# were a is defined as $$ a = \frac{e}{\pi} $$

# %% [markdown]
# ### An example of better latex

# %% [markdown]
# Some better latex can be shown by using sympy (currently not installed in the pdc anaconda yet)

# %%
# Lets define some symbols and matrices
a11, a12, a21, a22, b11, b12, b21, b22 = symbols('a11 a12 a21 a22 b11 b12 b21 b22')
A = Matrix([[a11, a12], [a21, a22]])
B = Matrix([[b11, b12], [b21, b22]])
A, B
# Out:
# ⎛⎡a₁₁  a₁₂⎤, ⎡b₁₁  b₁₂⎤⎞
# ⎜⎢        ⎥  ⎢        ⎥⎟
# ⎝⎣a₂₁  a₂₂⎦  ⎣b₂₁  b₂₂⎦⎠

# %%
# Matrix multiplication is made easy now
A * B
# Out:
# ⎡a₁₁⋅b₁₁ + a₁₂⋅b₂₁  a₁₁⋅b₁₂ + a₁₂⋅b₂₂⎤
# ⎢                                    ⎥
# ⎣a₂₁⋅b₁₁ + a₂₂⋅b₂₁  a₂₁⋅b₁₂ + a₂₂⋅b₂₂⎦

# %% [markdown]
# ### Spell checker

# %% [markdown]
# This one only works on a local installation right now. The first cell installs the extension, the second one loads it. Restart your notebook afterwards to see a new button that activates spell checking.

# %%
# First install the packages:
# sudo ipython install-nbextension https://bitbucket.org/ipre/calico/downloads/calico-spell-check-1.0.zip
# sudo ipython install-nbextension https://bitbucket.org/ipre/calico/downloads/calico-document-tools-1.0.zip
# sudo ipython install-nbextension https://bitbucket.org/ipre/calico/downloads/calico-cell-tools-1.0.zip

# %%
# %%javascript
# Jupyter.notebook.config.update({"load_extensions":{"calico-spell-check":true,
#                                                   "calico-document-tools":true,
#                                                   "calico-cell-tools":true}})

# %% [markdown]
# ## Figures

# %% [markdown]
# ### Just one image of a cat

# %%
Image(url='http://catbearding.com/wp-content/uploads/2013/06/cat_water_drip.gif')
# Out:
# <img src="http://catbearding.com/wp-content/uploads/2013/06/cat_water_drip.gif"/>

# %% [markdown]
# Lets set a folder name were we want to save all our plots

# %%
notebook_name = 'Ipython_example_presentation'

# Saves plots to plots/YYMMDD/...
plot_folder = os.path.join(notebook_name, strftime("%Y%m%d"))
plot_folder_web = os.path.join( plot_folder, "web")

# %% [markdown]
# ### Scatter plots

# %% [markdown]
# Lets start by plotting the s1 vs s2 in the most simplest way

# %%
plt.scatter(data['cs1'],data['cs2'])
plt.show()

# %% [markdown]
# Ok that looks awful, lets use some more options of matplotlib by defining our own scatter plot options.
#
# We run one notebook where we keep our plotting options: (this uses our plot_folder name)

# %%
# %run plot_functions.ipynb

# %% [markdown]
# Now we can make the plot more beautiful. The plot is automatically saved if we set:

# %%
# This saves our plots in png in 300 dpi and 50 dpi (for web)
save_plots = True
# This savesd out plots in pdf so that we can change stuff in it later on for our thesis :)
save_pdf_plots = True

# %% [markdown]
# Lets plot it again using our new scatter plot function which now has all the options we normally use in one line:

# %%
title = 'Fig 1. Corrected Light vs charge'
plot_scatter(data['cs1'],data['cs2'], 'cS1 (pe)', 'cS2 (pe)',
             title, xlim = [0,1500], ylim = [0,500000], 
             c =data['cs2']/data['cs1'], s =40, 
             marker = '.', edgecolors ='none', colorb =True, colorblabel = 'something',
             vmin = 0, vmax = 500)

# %%
x = [0, 1, 2, 3]

plt.figure()

# subplot 1
plt.subplot(121)
plt.bar(x, x)
set_axis( 'x','y','Fig 2a. title',)

# subplot 2
plt.subplot(122)
plt.plot(x, x)
set_axis( 'x','y','Fig 2b. title2',)

plt.show()
